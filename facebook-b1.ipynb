# %%
import pandas as pd

# %%
kk = pd.read_csv('/kaggle/input/b1assignment/Facebook.csv',sep=';')

# %%
kk.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
kk.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions'],
#       dtype='object')

# %%
kk.dtypes
# Out:
# Page total likes                                                         int64
# Type                                                                    object
# Category                                                                 int64
# Post Month                                                               int64
# Post Weekday                                                             int64
# Post Hour                                                                int64
# Paid                                                                   float64
# Lifetime Post Total Reach                                                int64
# Lifetime Post Total Impressions                                          int64
# Lifetime Engaged Users                                                   int64
# Lifetime Post Consumers                                                  int64
# Lifetime Post Consumptions                                               int64
# ...

# %%
kk.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
kk.shape
# Out:
# (500, 19)

# %%
subset = kk[['Page total likes','Category']]
subset
# Out:
#      Page total likes  Category
# 0              139441         2
# 1              139441         2
# 2              139441         3
# 3              139441         2
# 4              139441         2
# ..                ...       ...
# 495             85093         3
# 496             81370         2
# 497             81370         1
# 498             81370         3
# 499             81370         2
#
# [500 rows x 2 columns]

# %%
subset1 = kk.loc[1:7,['Page total likes']]
subset1
# Out:
#    Page total likes
# 1            139441
# 2            139441
# 3            139441
# 4            139441
# 5            139441
# 6            139441
# 7            139441

# %%
subset2 = kk[kk['Page total likes']>100000]
subset2
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 1              139441  Status         2          12             3         10
# 2              139441   Photo         3          12             3          3
# 3              139441   Photo         2          12             2         10
# 4              139441   Photo         2          12             2          3
# ..                ...     ...       ...         ...           ...        ...
# 433            100732   Photo         1           3             6         17
# 434            100732   Photo         1           3             6         15
# 435            100732   Photo         1           3             6         15
# 436            100732   Photo         1           3             6         13
# 437            100732   Photo         1           3             6         10
#
# ...

# %%
d1 = kk.head()
d2 = kk.tail()
pd.concat([d1,d2],axis=1)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441.0   Photo       2.0        12.0           4.0        3.0
# 1            139441.0  Status       2.0        12.0           3.0       10.0
# 2            139441.0   Photo       3.0        12.0           3.0        3.0
# 3            139441.0   Photo       2.0        12.0           2.0       10.0
# 4            139441.0   Photo       2.0        12.0           2.0        3.0
# 495               NaN     NaN       NaN         NaN           NaN        NaN
# 496               NaN     NaN       NaN         NaN           NaN        NaN
# 497               NaN     NaN       NaN         NaN           NaN        NaN
# 498               NaN     NaN       NaN         NaN           NaN        NaN
# 499               NaN     NaN       NaN         NaN           NaN        NaN
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
pd.concat([d1,d2],axis=1,join = 'inner')
# Out:
# Empty DataFrame
# Columns: [Page total likes, Type, Category, Post Month, Post Weekday, Post Hour, Paid, Lifetime Post Total Reach, Lifetime Post Total Impressions, Lifetime Engaged Users, Lifetime Post Consumers, Lifetime Post Consumptions, Lifetime Post Impressions by people who have liked your Page, Lifetime Post reach by people who like your Page, Lifetime People who have liked your Page and engaged with your post, comment, like, share, Total Interactions, Page total likes, Type, Category, Post Month, Post Weekday, Post Hour, Paid, Lifetime Post Total Reach, Lifetime Post Total Impressions, Lifetime Engaged Users, Lifetime Post Consumers, Lifetime Post Consumptions, Lifetime Post Impressions by people who have liked your Page, Lifetime Post reach by people who like your Page, Lifetime People who have liked your Page and engaged with your post, comment, like, share, Total Interactions]
# Index: []
#
# [0 rows x 38 columns]

# %%
d4 = kk[['Page total likes','Category']].head(3)
d3 = kk[['Category','Post Month']].head(3)
pd.merge(d4,d3)
# Out:
#    Page total likes  Category  Post Month
# 0            139441         2          12
# 1            139441         2          12
# 2            139441         2          12
# 3            139441         2          12
# 4            139441         3          12

# %%
kk.sort_values(by='Page total likes')
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370   Photo         2           1             4          4
# 496             81370   Photo         2           1             5          8
# 498             81370   Photo         3           1             4         11
# 497             81370   Photo         1           1             5          2
# 493             85093   Photo         3           1             1          2
# ..                ...     ...       ...         ...           ...        ...
# 10             139441  Status         2          12             5         10
# 11             139441   Photo         2          12             5         10
# 13             139441   Photo         2          12             5          3
# 7              139441   Photo         3          12             7          9
# 0              139441   Photo         2          12             4          3
#
# ...

# %%
kk.sort_values(by='Page total likes',ascending=False)
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441   Photo         2          12             4          3
# 8              139441  Status         2          12             7          3
# 1              139441  Status         2          12             3         10
# 12             139441   Photo         2          12             5         10
# 11             139441   Photo         2          12             5         10
# ..                ...     ...       ...         ...           ...        ...
# 495             85093   Photo         3           1             7          2
# 496             81370   Photo         2           1             5          8
# 497             81370   Photo         1           1             5          2
# 498             81370   Photo         3           1             4         11
# 499             81370   Photo         2           1             4          4
#
# ...

# %%
d5 = kk.transpose()
print(d5.shape)
d5
# Out:
# (19, 500)
#                                                        0       1       2    \
# Page total likes                                    139441  139441  139441
# Type                                                 Photo  Status   Photo
# Category                                                 2       2       3
# Post Month                                              12      12      12
# Post Weekday                                             4       3       3
# Post Hour                                                3      10       3
# Paid                                                   0.0     0.0     0.0
# Lifetime Post Total Reach                             2752   10460    2413
# Lifetime Post Total Impressions                       5091   19057    4373
# Lifetime Engaged Users                                 178    1457     177
# Lifetime Post Consumers                                109    1361     113
# ...

# %%
kk.shape
# Out:
# (500, 19)

# %%
pivot = pd.pivot_table(kk[['Page total likes','Post Month','Category']],index=['Page total likes','Category'])
pivot
# Out:
#                            Post Month
# Page total likes Category
# 81370            1                1.0
#                  2                1.0
#                  3                1.0
# 85093            3                1.0
# 85979            1                1.0
# ...                               ...
# 138895           1               12.0
#                  2               12.0
#                  3               12.0
# 139441           2               12.0
#                  3               12.0
#
# [181 rows x 1 columns]

# %%
kk.melt(id_vars=['Page total likes'],value_vars=['Category'])
# Out:
#      Page total likes  variable  value
# 0              139441  Category      2
# 1              139441  Category      2
# 2              139441  Category      3
# 3              139441  Category      2
# 4              139441  Category      2
# ..                ...       ...    ...
# 495             85093  Category      3
# 496             81370  Category      2
# 497             81370  Category      1
# 498             81370  Category      3
# 499             81370  Category      2
#
# [500 rows x 3 columns]
